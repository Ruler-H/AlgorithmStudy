# %%
# 백준 2676번 - 라스칼 삼각형
import sys
# input = sys.stdin.readline

t = int(input().strip())

for _ in range(t):
    n, m = map(int, input().strip().split())
    rascal = [1, n]
    for i in range(2, n // 2 + 1):
        rascal.append(rascal[i-1] * 2 - rascal[i-2] - 2)
    if n % 2 == 0:
        rascal.extend(rascal[:-1][::-1])
    else:
        rascal.extend(rascal[::-1])
    print(rascal[m])
# Out:
# 1
# 5
# 411495886
# 24383845
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 8
#       5 t = int(input().strip())
#       7 for _ in range(t):
# ----> 8     n, m = map(int, input().strip().split())
#       9     rascal = [1, n]
#      10     for i in range(2, n // 2 + 1):
#
# ValueError: not enough values to unpack (expected 2, got 0)
