# %%
# 백준 17903번 - Counting Clauses
import sys
# input = sys.stdin.readline

m, n = map(int, input().split())
for _ in range(m):
    input()  # clause 읽기만 하면 됨

if m < 8:
    print("unsatisfactory")
else:
    print("satisfactory")
