# %%
# 백준 5666번 - Hot Dogs
import sys
# input = sys.stdin.readline

while True:
    try:
        n, m = map(int, input().split())
        result = n / m
        print(f"{result:.2f}")
    except:
        break
