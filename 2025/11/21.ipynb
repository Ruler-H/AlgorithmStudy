# %%
# 백준 25858번 - Divide the Cash
import sys
# input = sys.stdin.readline

n, d = map(int, input().split())

scores = [int(input()) for _ in range(n)]

for i in range(n):
    print(scores[i] * d // sum(scores))
