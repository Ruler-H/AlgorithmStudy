# %%
# 백준 24183번 - Affischutskicket
import sys
# input = sys.stdin.readline

a, b, c = map(int, input().split())

result = 0
result += a * (0.229 * 0.324) * 2
result += b * (0.297 * 0.420) * 2
result += c * (0.210 * 0.297)
print(result)
# Out:
# 44.62614000000001
