# %%
# 백준 26531번 - Simple Sum
import sys
# input = sys.stdin.readline

inp_str = input().strip()

if int(inp_str[0]) + int(inp_str[4]) == int(inp_str[8]):
    print("YES")
else:
    print("NO")
# Out:
# -15
