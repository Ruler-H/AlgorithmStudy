# %%
# 백준 20839번 - Betygsättning
import sys
# input = sys.stdin.readline

x, y, z = map(int, input().split())
xa, ya, za = map(int, input().split())

if xa == x and ya == y:
    print('A')
elif ya == y and xa >= x / 2:
    print('B')
elif ya == y:
    print('C')
elif ya >= y / 2:
    print('D')
else:
    print('E')
