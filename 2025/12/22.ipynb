# %%
# 백준 34073번 - DORO
import sys
# input = sys.stdin.readline

N = int(input())
words = list(map(str, input().split()))
for i in range(N):
    print(words[i] + "DORO", end=" ")
# Out:
# i love youDORO DORO DORO
