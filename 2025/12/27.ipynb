# %%
# 백준 4539번 - 반올림
import sys
# input = sys.stdin.readline

n = int(input())
for _ in range(n):
    x = int(input())
    base = 10
    while x > base:
        x = (x + base // 2) // base * base
        base *= 10
    print(x)
