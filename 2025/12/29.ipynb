# %%
# 백준 30876번 - Tren del Fin del Mundo
import sys
# input = sys.stdin.readline

N = int(input())

x, y = map(int, input().split())

for _ in range(N-1):
    xi, yi = map(int, input().split())
    if yi < y:
        x, y = xi, yi

print(x, y)
