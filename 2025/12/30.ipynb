# %%
# 백준 23530번 - Not A + B
import sys
# input = sys.stdin.readline

t = int(input())

for _ in range(t):
    a, b = map(int, input().split())
    if a + b != 1:
        print(1)
    else:
        print(2)
# Out:
# 18
