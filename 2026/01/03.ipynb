# %%
# 백준 11772번 - POT
import sys
# input = sys.stdin.readline

N = int(input())

result = 0

for _ in range(N):
    P = input().strip()
    result += int(P[:-1]) ** int(P[-1])

print(result)
# Out:
# 1953566
