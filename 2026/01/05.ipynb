# %%
# 백준 34217번 - 찾아오시는 길
import sys
# input = sys.stdin.readline

A, B = map(int, input().split())
C, D = map(int, input().split())

if A + C > B + D:
    print("Yongdap")
elif A + C < B + D:
    print("Hanyang Univ.")
else:
    print("Either")
