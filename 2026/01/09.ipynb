# %%
# 백준 26592번 - Triangle Height
import sys
# input = sys.stdin.readline

n = int(input())

for _ in range(n):
    b, h = map(float, input().split())
    result = (2 * b) / h
    print(f"The height of the triangle is {result:.2f} units")
# Out:
# The height of the triangle is 9.90 units
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 8
#       5 n = int(input())
#       7 for _ in range(n):
# ----> 8     b, h = map(float, input().split())
#       9     result = (2 * b) / h
#      10     print(f"The height of the triangle is {result:.2f} units")
#
# ValueError: not enough values to unpack (expected 2, got 0)
