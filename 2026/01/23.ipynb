# %%
# 백준 26500번 - Absolutely
import sys
# input = sys.stdin.readline

n = int(input())

for _ in range(n):
    a, b = map(float, input().split())
    result = abs(a - b)
    print(f"{result:.1f}")
# Out:
# 6
