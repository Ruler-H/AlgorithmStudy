# %%
# 백준 26768번 - H4x0r
import sys
# input = sys.stdin.readline

W = input()

hacker = {
    'a': '4',
    'e': '3',
    'i': '1',
    'o': '0',
    's': '5'
}

for w in W:
    if w in hacker:
        print(hacker[w], end='')
    else:
        print(w, end='')
# Out:
# 13332
