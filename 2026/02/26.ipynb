# %%
# 백준 34691번 - 대전과학고등학교를 사랑하십니까?
import sys
# input = sys.stdin.readline

hacmyeong = {
    "animal": "Panthera tigris",
    "tree": "Pinus densiflora",
    "flower": "Forsythia koreana"
}

while True:
    inp_str = input().strip()
    if inp_str == "end":
        break
    print(hacmyeong[inp_str])
# Out:
# 1 3 2 4 5 6
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /Users/benny/.pyenv/versions/3.13.0/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3709: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
