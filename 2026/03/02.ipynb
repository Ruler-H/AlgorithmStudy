# %%
# 백준 25991번 - Lots of Liquid
import sys
# input = sys.stdin.readline

n = int(input())

result = 0

nums = list(map(float, input().split()))

for num in nums:
    result += (num ** 3)

print(result ** (1 / 3))
# Out:
# 41.99999999999999
