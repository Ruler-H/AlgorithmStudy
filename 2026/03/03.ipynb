# %%
# 백준 30700번 - KOREA 문자열 만들기
import sys
# input = sys.stdin.readline

S = input()

cnt = 0
korea = 'KOREA'

for i in range(len(S)):
    if S[i] == korea[cnt % 5]:
        cnt += 1

print(cnt)
# Out:
# 0
