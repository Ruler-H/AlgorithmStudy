# %%
# 백준 33698번 - CPDU
import sys
# input = sys.stdin.readline

N = int(input())

cnt = 0
for _ in range(N):
    contest_title = input()
    if contest_title.startswith("C"):
        cnt += 1

print(cnt)
# Out:
# Yes
# No
