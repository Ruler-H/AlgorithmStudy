# %%
# 백준 26767번 - Hurra!
import sys
# input = sys.stdin.readline

N = int(input())

for i in range(1, N + 1):
    if i % 7 == 0:
        if i % 11 != 0:
            print("Hurra!")
        else:
            print("Wiwat!")
    elif i % 11 == 0:
        print("Super!")
    else:
        print(i)
# Out:
# Yes
# No
