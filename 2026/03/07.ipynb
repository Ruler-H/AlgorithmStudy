# %%
# 백준 16546번 - Missing Runners
import sys
# input = sys.stdin.readline

N = int(input())
result = sum(range(1, N + 1))

result -= sum(map(int, input().strip().split()))

print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       6 result = sum(range(1, N + 1))
#       8 result -= sum(map(int, input().strip().split()))
# ---> 10 print(result())
#
# TypeError: 'int' object is not callable
