# %%
# 백준 34813번 - 공통교육과정
import sys
# input = sys.stdin.readline

subject_num = input()

if subject_num[0] == 'F':
    print("Foundation")
elif subject_num[0] == 'C':
    print("Claves")
elif subject_num[0] == 'V':
    print("Veritas")
else:
    print("Exploration")
