# %%
# 백준 20113번 - 긴급 회의
import sys
# input = sys.stdin.readline

N = int(input())
player = [0 for _ in range(N + 1)]
votes = list(map(int, input().split()))
for vote in votes:
    if vote > 0:
        player[vote] += 1

max_vote = max(player)
max_player = player.index(max_vote)
max_cnt = player.count(max_vote)

if max_cnt > 1:
    print("skipped")
else:
    print(max_player)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 9
#       6 player = [0 for _ in range(N + 1)]
#       8 for _ in range(N):
# ----> 9     vote = int(input())
#      10     if vote > 0:
#      11         player[vote] += 1
#
# ValueError: invalid literal for int() with base 10: '3 1 4 3 0'
