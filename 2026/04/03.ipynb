# %%
# 백준 6784번 - Multiple Choice
import sys
# input = sys.stdin.readline

N = int(input())

result = 0

answers = []
for i in range(N):
    answers.append(input().strip())

for i in range(N):
    if answers[i] == input().strip():
        result += 1

print(result)
